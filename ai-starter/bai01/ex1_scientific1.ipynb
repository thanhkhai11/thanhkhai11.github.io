# %% [markdown]
# # ex1_scientific1
# ## Nội dung bài
# Hiển thị ngẫu nhiên $N = 50$ hình tròn:
# + Tâm $c_i = (x_i,y_i)$ ngẫu nhiên với $x_i, y_i \\in \\left[0, 1 \\right]$
# + Màu sắc $color_i$ ngẫu nhiên với $color_i \\in \\left[0, 1 \\right]$
# + Diện tích $area_i = \\pi * r_i^2$ với sinh ngẫu nhiên $r_i \\in \\left[0, 1 \\right]$
# ## Bài làm

# %% [markdown]
# ### Import thư viện

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display # hiển thị rich output

# %% [markdown]
# ### Sinh ngẫu nhiên hình tròn

# %%
# %time
    # generate randomly the center (x,y ) of circle, color, area
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N)) ** 2 # 0 to 15 point radii
# Out:
# CPU times: user 2 μs, sys: 0 ns, total: 2 μs
# Wall time: 5.48 μs

# %%
# Mã kiểm tra dữ liệu
print(f'+ x: len={len(x):d}, [{min(x):.2f}, {max(x):.2f}]: 10 samples [{x[0:10]}]')
print(f'+ y: len={len(y):d}, [{min(y):.2f}, {max(y):.2f}]: 10 samples [{y[0:10]}]')
print(f'+ colors: len={len(colors):d}, [{min(colors):.2f}, {max(colors):.2f}]: 10 samples [{colors[0:10]}]')
print(f'+ area: len={len(area):d}, [{min(area):.2f}, {max(area):.2f}]: 10 samples [{area[0:10]}]')
# Out:
# + x: len=50, [0.03, 1.00]: 10 samples [[0.26031867 0.29486068 0.59894827 0.8025387  0.22340919 0.93647741
#  0.88611574 0.25412446 0.3988992  0.03712878]]
# + y: len=50, [0.04, 0.97]: 10 samples [[0.83120917 0.87350643 0.67149895 0.57129879 0.25865192 0.26783823
#  0.1756462  0.7727512  0.2867429  0.79519437]]
# + colors: len=50, [0.04, 0.98]: 10 samples [[0.42544437 0.80634909 0.19141949 0.97469921 0.98344405 0.52987626
#  0.82875718 0.05554275 0.67145498 0.9002038 ]]
# + area: len=50, [0.01, 675.64]: 10 samples [[ 31.1232948    6.62718885 396.09063877  17.40493336  42.85652455
#  560.37233404 286.95204809 480.62050488 188.71069413 114.43760616]]

# %% [markdown]
# ### Hiển thị đồ thị

# %%
# %matplotlib inline
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# ## Kết thúc
